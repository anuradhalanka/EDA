# %% [markdown]
# #### import required packages :

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt   # lib means library
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %% [markdown]
# #### Read the data :

# %%
visa_df=pd.read_csv(r"C:\Users\Adireddy\Documents\Naresh IT Data Science & AI\Data files\visadataset - visadataset.csv")
visa_df
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %% [markdown]
# #### head :

# %% [markdown]
# - top 5 rows
# - by default returns 5 rows, if you don't pass anything inside ()
# - if you want to top 10 columns need to pass 10 inside ()

# %%
visa_df.head()
# Out:
#   case_id continent education_of_employee has_job_experience  \
# 0  EZYV01      Asia           High School                  N
# 1  EZYV02      Asia              Master's                  Y
# 2  EZYV03      Asia            Bachelor's                  N
# 3  EZYV04      Asia            Bachelor's                  N
# 4  EZYV05    Africa              Master's                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# 2                     Y            44444         2008                 West
# 3                     N               98         1897                 West
# 4                     N             1082         2005                South
#
#    prevailing_wage unit_of_wage full_time_position case_status
# 0         592.2029         Hour                  Y      Denied
# ...

# %%
visa_df.head(10)
# Out:
#   case_id      continent education_of_employee has_job_experience  \
# 0  EZYV01           Asia           High School                  N
# 1  EZYV02           Asia              Master's                  Y
# 2  EZYV03           Asia            Bachelor's                  N
# 3  EZYV04           Asia            Bachelor's                  N
# 4  EZYV05         Africa              Master's                  Y
# 5  EZYV06           Asia              Master's                  Y
# 6  EZYV07           Asia            Bachelor's                  N
# 7  EZYV08  North America            Bachelor's                  Y
# 8  EZYV09           Asia            Bachelor's                  N
# 9  EZYV10         Europe             Doctorate                  Y
#
#   requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 0                     N            14513         2007                 West
# 1                     N             2412         2002            Northeast
# ...

# %% [markdown]
# #### tail :

# %% [markdown]
# - last 5 rows
# - in head and tail default number of rows are 5
# - if you want any other number of rows pass that number inside ()

# %%
visa_df.tail()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 25475                     Y             2601         2008
# 25476                     N             3274         2006
# 25477                     N             1121         1910
# 25478                     Y             1918         1887
# 25479                     N             3195         1960
#
#       region_of_employment  prevailing_wage unit_of_wage full_time_position  \
# 25475                South         77092.57         Year                  Y
# ...

# %% [markdown]
# #### shape :

# %% [markdown]
# - number of rows and number of columns

# %%
visa_df.shape
# Out:
# (25480, 12)

# %%
# 25480 is number of rows
# 12 is number of columns

# %%
print(f"the number of rows are {visa_df.shape[0]}")
print(f"the number of columns are {visa_df.shape[1]}")
# 0 means rows
# 1 means columns
# Out:
# the number of rows are 25480
# the number of columns are 12

# %% [markdown]
# #### size :

# %% [markdown]
# - number of rows * number of columns

# %%
visa_df.size
# Out:
# 305760

# %%
25480*12
# Out:
# 305760

# %% [markdown]
# #### columns:

# %%
visa_df.columns   # will give all column names
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %% [markdown]
# #### dtypes :

# %%
visa_df.dtypes
# Out:
# case_id                   object
# continent                 object
# education_of_employee     object
# has_job_experience        object
# requires_job_training     object
# no_of_employees            int64
# yr_of_estab                int64
# region_of_employment      object
# prevailing_wage          float64
# unit_of_wage              object
# full_time_position        object
# case_status               object
# dtype: object

# %% [markdown]
# - object means categorical
# - int, float means numerical
# - understanding datatypes are very important
# - 'visa_df' type is: DataFrame  (dataframe contains columns and rows)
# - 'visa_df.dtypes' is: series
# - series objects can convert into dictionary, after that you can use dictionary methods

# %%
type(visa_df)
# Out:
# pandas.core.frame.DataFrame

# %%
type(visa_df.dtypes)
# Out:
# pandas.core.series.Series

# %% [markdown]
# $task$ :
# - create categorical columns list
# - create numerical columns list
#
# $Idea$
# - convert series type into dictionary
# - iterate through the loop
# - apply the condition get the results in the list

# %%
dict(visa_df.dtypes)  # key value pairs returns
# Out:
# {'case_id': dtype('O'),
#  'continent': dtype('O'),
#  'education_of_employee': dtype('O'),
#  'has_job_experience': dtype('O'),
#  'requires_job_training': dtype('O'),
#  'no_of_employees': dtype('int64'),
#  'yr_of_estab': dtype('int64'),
#  'region_of_employment': dtype('O'),
#  'prevailing_wage': dtype('float64'),
#  'unit_of_wage': dtype('O'),
#  'full_time_position': dtype('O'),
#  'case_status': dtype('O')}

# %%
# converts series into dictionary

# %%
dtypes=dict(visa_df.dtypes)
for key,value in dtypes.items():
    if value in ['object']:
        print(key)
# Out:
# case_id
# continent
# education_of_employee
# has_job_experience
# requires_job_training
# region_of_employment
# unit_of_wage
# full_time_position
# case_status

# %%
cat_cols=[key for key,value in dtypes.items() if value=='object']    # categorical columns list
cat_cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'region_of_employment',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
num_cols=[key for key,value in dtypes.items() if value!='object']    # numerical columns list
num_cols
# Out:
# ['no_of_employees', 'yr_of_estab', 'prevailing_wage']

# %% [markdown]
# #### select data types :

# %% [markdown]
# - select data types will give a dataframe of desired data types
# - the result also a dataframe
# - all above options like head, tail columns

# %%
visa_df.select_dtypes(include='object')     # do shift+tab inside () to know what we need to pass inside ()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training region_of_employment unit_of_wage  \
# 0                         N                 West         Hour
# ...

# %%
# shortcut for the previous task to create categorical, numerical columns list
# include=object returns categorical columns
# exclude=object returns numerical columns

# %%
visa_df.select_dtypes(include='object').columns
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'region_of_employment', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
visa_df.select_dtypes(exclude='object').columns
# Out:
# Index(['no_of_employees', 'yr_of_estab', 'prevailing_wage'], dtype='object')

# %% [markdown]
# #### isnull:

# %% [markdown]
# - isnull used to identify the any missing/null values are available
# - isnull means we are asking a question to the computer
# - It will give True or False answer
# - True: yes value missed
# - False: no value missed

# %% [markdown]
# $Note$ :
# - If we see bound method means add the brackets at the end
# - for visa_df.isnull bound method will come in the first line of output

# %%
visa_df.isnull
# Note: If you see bound method  at the start of output means we forgot to add the brackets at the end
visa_df.isnull()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %% [markdown]
# #### isna :

# %%
visa_df.isna()
# Out:
#        case_id  continent  education_of_employee  has_job_experience  \
# 0        False      False                  False               False
# 1        False      False                  False               False
# 2        False      False                  False               False
# 3        False      False                  False               False
# 4        False      False                  False               False
# ...        ...        ...                    ...                 ...
# 25475    False      False                  False               False
# 25476    False      False                  False               False
# 25477    False      False                  False               False
# 25478    False      False                  False               False
# 25479    False      False                  False               False
#
#        requires_job_training  no_of_employees  yr_of_estab  \
# 0                      False            False        False
# ...

# %%
# visa_df.isnull() , visa_df.isna() both are same

# %%
visa_df.isnull().sum()
# Out:
# case_id                  0
# continent                0
# education_of_employee    0
# has_job_experience       0
# requires_job_training    0
# no_of_employees          0
# yr_of_estab              0
# region_of_employment     0
# prevailing_wage          0
# unit_of_wage             0
# full_time_position       0
# case_status              0
# dtype: int64

# %%
# gives sum of null values count in each column in the visa_df dataframe
# instead of 0, if any number is there in the output, that many null values are available in that column

# %% [markdown]
# #### drop-duplicates :
# - If any duplicates rows are there then we can drop it

# %%
visa_df.drop_duplicates()
# Out:
#          case_id continent education_of_employee has_job_experience  \
# 0         EZYV01      Asia           High School                  N
# 1         EZYV02      Asia              Master's                  Y
# 2         EZYV03      Asia            Bachelor's                  N
# 3         EZYV04      Asia            Bachelor's                  N
# 4         EZYV05    Africa              Master's                  Y
# ...          ...       ...                   ...                ...
# 25475  EZYV25476      Asia            Bachelor's                  Y
# 25476  EZYV25477      Asia           High School                  Y
# 25477  EZYV25478      Asia              Master's                  Y
# 25478  EZYV25479      Asia              Master's                  Y
# 25479  EZYV25480      Asia            Bachelor's                  Y
#
#       requires_job_training  no_of_employees  yr_of_estab  \
# 0                         N            14513         2007
# ...

# %%
visa_df.drop_duplicates().all()
# Out:
# case_id                  True
# continent                True
# education_of_employee    True
# has_job_experience       True
# requires_job_training    True
# no_of_employees          True
# yr_of_estab              True
# region_of_employment     True
# prevailing_wage          True
# unit_of_wage             True
# full_time_position       True
# case_status              True
# dtype: bool

# %%
# True means those columns has duplicates

# %% [markdown]
# $Note$ :
# - If you close the jupyter notebook and when you open new jupyter notebook everytime we need to import all required packages
# - import pandas, numpy,matplotlib.pyplot, seaborn packages
# - read the data from file again

# %% [markdown]
# #### info :

# %%
visa_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25480 entries, 0 to 25479
# Data columns (total 12 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   case_id                25480 non-null  object
#  1   continent              25480 non-null  object
#  2   education_of_employee  25480 non-null  object
#  3   has_job_experience     25480 non-null  object
#  4   requires_job_training  25480 non-null  object
#  5   no_of_employees        25480 non-null  int64
#  6   yr_of_estab            25480 non-null  int64
#  7   region_of_employment   25480 non-null  object
#  8   prevailing_wage        25480 non-null  float64
#  9   unit_of_wage           25480 non-null  object
#  10  full_time_position     25480 non-null  object
#  11  case_status            25480 non-null  object
# dtypes: float64(1), int64(2), object(9)
# memory usage: 2.3+ MB

# %%
# gives the information of all columns like type of visa_df, rangeindex, number of columns, 
# datatypes of each column, number of not null entries in each column, memory usage

# %% [markdown]
# #### take :

# %% [markdown]
# - If you want to get middle data
# - Take option is used to extract the particular index of data
# - take has one parameter called axis
# - axis=1 represents columns
# - axis=0 represents rows
# - bydefault axis=0 is there
# - in below example we give 100,200,300 and we did not provide axis values
# - I understood we are talking about rows as axis=0 bydefault

# %%
visa_df.take([100,200,300])   # returns row number 100,200,300
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.take([100,200,300],axis=1)  # gives error as axis=1 means columns and we don't have 100,200,300 column numbers
# bydefault axis=0  means rows, if you do shift+tab  in () you can see that
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[36], line 1
# ----> 1 visa_df.take([100,200,300],axis=1)
#
# File ~\anaconda3\Lib\site-packages\pandas\core\generic.py:4068, in NDFrame.take(self, indices, axis, **kwargs)
#    4063     # We can get here with a slice via DataFrame.__getitem__
#    4064     indices = np.arange(
#    4065         indices.start, indices.stop, indices.step, dtype=np.intp
#    4066     )
# -> 4068 new_data = self._mgr.take(
#    4069     indices,
#    4070     axis=self._get_block_manager_axis(axis),
#    4071     verify=True,
#    4072 )
#    4073 return self._constructor_from_mgr(new_data, axes=new_data.axes).__finalize__(
#    4074     self, method="take"
#    4075 )
#
# File ~\anaconda3\Lib\site-packages\pandas\core\internals\managers.py:874, in BaseBlockManager.take(self, indexer, axis, verify)
# ...

# %%
visa_df.take([2,5,7],axis=1) # gives o/p as column numbers 3rd,6th,8th as python index starts with 0
# Out:
#       education_of_employee  no_of_employees region_of_employment
# 0               High School            14513                 West
# 1                  Master's             2412            Northeast
# 2                Bachelor's            44444                 West
# 3                Bachelor's               98                 West
# 4                  Master's             1082                South
# ...                     ...              ...                  ...
# 25475            Bachelor's             2601                South
# 25476           High School             3274            Northeast
# 25477              Master's             1121                South
# 25478              Master's             1918                 West
# 25479            Bachelor's             3195              Midwest
#
# [25480 rows x 3 columns]

# %%
visa_df.take[100:105]   # slicing won't work here, gives error
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[38], line 1
# ----> 1 visa_df.take[100:105]
#
# TypeError: 'method' object is not subscriptable

# %% [markdown]
# $Note$ :
# - we can't take rows and columns at a time in one single take

# %%
# Question:
# I want to take rows: 100,200,300 and columns: 2,5,7
# with single syntax not possible
# need to use 2 takes, one for rows and second for columns 
# and need to mention axis=1 for columns

visa_df.take([100,200,300]).take([2,5,7],axis=1)
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %% [markdown]
# #### iloc :
# - to solve the problem in take we use iloc
# - rows and columns at a time is possible using iloc

# %%
# syntax:
# visa_df.iloc[<rows>,<columns>]
# visa_df.iloc[<start:end>,<start:end>]
# rows=[100,200,300]
# columns=[2,5,7]

# %%
visa_df.iloc[[100,200,300],[2,5,7]]
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 200             Doctorate             3282                 West
# 300              Master's             3268              Midwest

# %%
visa_df.iloc[[100,200,300]]  # same like take it works
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
# 200  EZYV201      Asia             Doctorate                  Y
# 300  EZYV301      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
# 200                     N             3282         1979                 West
# 300                     N             3268         2012              Midwest
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified
# 200         74441.11         Year                  Y   Certified
# 300        101371.21         Year                  Y   Certified

# %%
visa_df.iloc[100:105,[2,5,7]]   # slicing also working
# Out:
#     education_of_employee  no_of_employees region_of_employment
# 100              Master's             2227            Northeast
# 101              Master's              334              Midwest
# 102            Bachelor's              224              Midwest
# 103             Doctorate              367                 West
# 104              Master's              306            Northeast

# %%
visa_df.iloc[100:105,2:5]
# returns 100 to 104 row numbers and 3rd,4th,5th columns as python index starts from 0
# Out:
#     education_of_employee has_job_experience requires_job_training
# 100              Master's                  Y                     N
# 101              Master's                  Y                     N
# 102            Bachelor's                  Y                     N
# 103             Doctorate                  Y                     N
# 104              Master's                  Y                     N

# %%
visa_df.iloc[100:105,2]
# Out:
# 100      Master's
# 101      Master's
# 102    Bachelor's
# 103     Doctorate
# 104      Master's
# Name: education_of_employee, dtype: object

# %%
visa_df.iloc[100:105,[2]]
# Out:
#     education_of_employee
# 100              Master's
# 101              Master's
# 102            Bachelor's
# 103             Doctorate
# 104              Master's

# %% [markdown]
# $Note$ :
# - no square brackets returns series datatype
# - with square brackets returns dataframe datatype

# %%
visa_df.iloc[100,2:5]
# Out:
# education_of_employee    Master's
# has_job_experience              Y
# requires_job_training           N
# Name: 100, dtype: object

# %%
visa_df.iloc[[100],2:5]
# Out:
#     education_of_employee has_job_experience requires_job_training
# 100              Master's                  Y                     N

# %% [markdown]
# #### to get 100th row with all columns

# %%
visa_df.iloc[[100]]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100],:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[[100],0:]
# Out:
#      case_id continent education_of_employee has_job_experience  \
# 100  EZYV101      Asia              Master's                  Y
#
#     requires_job_training  no_of_employees  yr_of_estab region_of_employment  \
# 100                     N             2227         2007            Northeast
#
#      prevailing_wage unit_of_wage full_time_position case_status
# 100         28243.79         Year                  Y   Certified

# %%
visa_df.iloc[100]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %%
visa_df.iloc[100,:]
# Out:
# case_id                    EZYV101
# continent                     Asia
# education_of_employee     Master's
# has_job_experience               Y
# requires_job_training            N
# no_of_employees               2227
# yr_of_estab                   2007
# region_of_employment     Northeast
# prevailing_wage           28243.79
# unit_of_wage                  Year
# full_time_position               Y
# case_status              Certified
# Name: 100, dtype: object

# %% [markdown]
# -  no square bracket means series
# -  visa_df.iloc[[100]], visa_df.iloc[[100],:], visa_df.iloc[[100],0:] returns 100th row with all columns

# %%
# to get only number of employees column data
# no_of_employees data

visa_df.iloc[:,[5]]
# Out:
#        no_of_employees
# 0                14513
# 1                 2412
# 2                44444
# 3                   98
# 4                 1082
# ...                ...
# 25475             2601
# 25476             3274
# 25477             1121
# 25478             1918
# 25479             3195
#
# [25480 rows x 1 columns]

# %%
# returns all rows and index is 5 for no_of_employees column (index starts from 0 for python)

# %%
l=['A','B','D']
l.index('D')
# Out:
# 2

# %%
visa_df.columns     # to get all column names list
# Out:
# Index(['case_id', 'continent', 'education_of_employee', 'has_job_experience',
#        'requires_job_training', 'no_of_employees', 'yr_of_estab',
#        'region_of_employment', 'prevailing_wage', 'unit_of_wage',
#        'full_time_position', 'case_status'],
#       dtype='object')

# %%
type(visa_df.columns)   # returns data type of visa_df.columns
# Out:
# pandas.core.indexes.base.Index

# %%
cols=list(visa_df.columns)    # to convert into list and store in variable cols(columns)
cols
# Out:
# ['case_id',
#  'continent',
#  'education_of_employee',
#  'has_job_experience',
#  'requires_job_training',
#  'no_of_employees',
#  'yr_of_estab',
#  'region_of_employment',
#  'prevailing_wage',
#  'unit_of_wage',
#  'full_time_position',
#  'case_status']

# %%
cols.index('no_of_employees')
# Out:
# 5

# %% [markdown]
# #### loc :
# - loc will take column names directly

# %%
visa_df.loc[[100,200,300],['no_of_employees']]

# if you put [] for no_of_employees, dataframe will come as o/p
# Out:
#      no_of_employees
# 100             2227
# 200             3282
# 300             3268

# %%
# returns 100,200,300th rows of no_of_employees column

# %%
# without using [] for no_of_employees column returns series

visa_df.loc[[100,200,300],'no_of_employees']
# Out:
# 100    2227
# 200    3282
# 300    3268
# Name: no_of_employees, dtype: int64

# %%
type(visa_df.loc[[100,200,300],'no_of_employees'])
# Out:
# pandas.core.series.Series
